# %%
import sys
print(sys.executable)
# Out:
# c:\Users\LENOVO\restaurant-revenue-prediction-system\.venv\Scripts\python.exe

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
import pickle

with open('../models/trained/best_model.pkl', 'rb') as f:
    model = pickle.load(f)

print(type(model))
# Out:
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
